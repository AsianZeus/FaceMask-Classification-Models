# %%
# %%capture
! pip install datasets transformers

# %%
# %cd MaskDetection/
# Out:
# /content/drive/MyDrive/MaskDetection

# %%
import torch
import torchvision.transforms as transforms
import os
import pandas as pd
from skimage import io
from torch.utils.data import (
    Dataset,
)

from transformers import ViTFeatureExtractor

model_name_or_path = 'google/vit-base-patch16-224-in21k'
feature_extractor = ViTFeatureExtractor.from_pretrained(model_name_or_path)

class FeatureExtractor(object):
    def __call__(self, image, target):
        sample = feature_extractor(image, return_tensors='pt')
        sample["labels"] = target
        return sample

class MaskDataset(Dataset):
    def __init__(self, csv_file, root_dir, transform=None):
        self.annotations = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform

    def __len__(self):
        return len(self.annotations)

    def __getitem__(self, index):
        img_path = os.path.join(self.root_dir, self.annotations.iloc[index, 0])
        image = io.imread(img_path)
        y_label = torch.tensor(int(self.annotations.iloc[index, 1]))
        
        data = self.transform(image,y_label)

        return data

train_ds = MaskDataset(
    csv_file="train.csv",
    root_dir="",
    transform=FeatureExtractor(),
)

test_ds = MaskDataset(
    csv_file="test.csv",
    root_dir="",
    transform=FeatureExtractor(),
)
# Out:
# Downloading:   0%|          | 0.00/160 [00:00<?, ?B/s]

# %%
train_ds.__getitem__(0)
# Out:
# {'pixel_values': tensor([[[[-0.2471, -0.2471, -0.2471,  ..., -0.3882, -0.3882, -0.3882],
#           [-0.2471, -0.2471, -0.2471,  ..., -0.3882, -0.3882, -0.3882],
#           [-0.2471, -0.2471, -0.2471,  ..., -0.3882, -0.3882, -0.3882],
#           ...,
#           [ 0.9137,  0.9137,  0.9137,  ...,  0.9608,  0.9608,  0.9608],
#           [ 0.9137,  0.9137,  0.9137,  ...,  0.9608,  0.9608,  0.9608],
#           [ 0.9137,  0.9137,  0.9137,  ...,  0.9608,  0.9608,  0.9608]],
#
#          [[-0.6078, -0.6078, -0.6078,  ..., -0.5686, -0.5686, -0.5686],
#           [-0.6078, -0.6078, -0.6078,  ..., -0.5686, -0.5686, -0.5686],
#           [-0.6078, -0.6078, -0.6078,  ..., -0.5686, -0.5686, -0.5686],
#           ...,
#           [ 0.8824,  0.8824,  0.8824,  ...,  0.8118,  0.8118,  0.8118],
#           [ 0.8824,  0.8824,  0.8824,  ...,  0.8118,  0.8118,  0.8118],
#           [ 0.8824,  0.8824,  0.8824,  ...,  0.8118,  0.8118,  0.8118]],
#
#          [[-0.7333, -0.7333, -0.7333,  ..., -0.6157, -0.6157, -0.6157],
#           [-0.7333, -0.7333, -0.7333,  ..., -0.6157, -0.6157, -0.6157],
#           [-0.7333, -0.7333, -0.7333,  ..., -0.6157, -0.6157, -0.6157],
#           ...,
#           [ 0.8588,  0.8588,  0.8588,  ...,  0.7804,  0.7804,  0.7804],
#           [ 0.8588,  0.8588,  0.8588,  ...,  0.7804,  0.7804,  0.7804],
#           [ 0.8588,  0.8588,  0.8588,  ...,  0.7804,  0.7804,  0.7804]]]]), 'labels': tensor(1)}

# %%
import numpy as np
from datasets import load_metric

metric = load_metric("accuracy")
def compute_metrics(p):
    return metric.compute(predictions=np.argmax(p.predictions, axis=1), references=p.label_ids)
# Out:
# Downloading:   0%|          | 0.00/1.41k [00:00<?, ?B/s]

# %%
from transformers import ViTForImageClassification

labels = ["No Mask","Mask"]

model = ViTForImageClassification.from_pretrained(
    model_name_or_path,
    num_labels=len(labels),
    id2label={str(i): c for i, c in enumerate(labels)},
    label2id={c: str(i) for i, c in enumerate(labels)}
)
# Out:
# Downloading:   0%|          | 0.00/502 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/330M [00:00<?, ?B/s]
# Some weights of the model checkpoint at google/vit-base-patch16-224-in21k were not used when initializing ViTForImageClassification: ['pooler.dense.bias', 'pooler.dense.weight']
# - This IS expected if you are initializing ViTForImageClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ViTForImageClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ViTForImageClassification were not initialized from the model checkpoint at google/vit-base-patch16-224-in21k and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
from transformers import TrainingArguments
from transformers import EarlyStoppingCallback

training_args = TrainingArguments(
  output_dir="./vit-base-mask-finetuned",
  per_device_train_batch_size=16,
  evaluation_strategy="steps",
  num_train_epochs=4,
  save_total_limit = 4, # Only last 4 models are saved. Older ones are deleted.
  fp16=True,
  save_steps=100,
  eval_steps=100,
  logging_steps=10,
  learning_rate=2e-4,
  remove_unused_columns=False,
  push_to_hub=False,
  report_to='tensorboard',
  load_best_model_at_end=True,
)
# Out:
# PyTorch: setting up devices

# %%
import torch

def collate_fn(batch):
    return {
        'pixel_values': torch.stack([x['pixel_values'][0] for x in batch]),
        'labels': torch.tensor([x['labels'] for x in batch])
    }

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    args=training_args,
    data_collator=collate_fn,
    compute_metrics=compute_metrics,
    train_dataset=train_ds,
    eval_dataset=test_ds,
    tokenizer=feature_extractor,
    callbacks = [EarlyStoppingCallback(early_stopping_patience=3)]
)
# Out:
# Using amp half precision backend

# %%
train_results = trainer.train()
trainer.save_model()
trainer.log_metrics("train", train_results.metrics)
trainer.save_metrics("train", train_results.metrics)
trainer.save_state()
# Out:
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:309: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use thePyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 14428
#   Num Epochs = 4
#   Instantaneous batch size per device = 16
#   Total train batch size (w. parallel, distributed & accumulation) = 16
#   Gradient Accumulation steps = 1
#   Total optimization steps = 3608
#     <div>
#
#       <progress value='773' max='3608' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 773/3608 37:24 < 2:17:33, 0.34 it/s, Epoch 0.86/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.021400</td>
#       <td>0.155222</td>
#       <td>0.961346</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.041500</td>
#       <td>0.061964</td>
#       <td>0.986374</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.037200</td>
#       <td>0.058919</td>
#       <td>0.984983</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.073800</td>
#       <td>0.173725</td>
#       <td>0.927419</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.009600</td>
#       <td>0.039475</td>
#       <td>0.989433</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.058400</td>
#       <td>0.175120</td>
#       <td>0.949944</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.009700</td>
#       <td>0.045691</td>
#       <td>0.987764</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 3596
#   Batch size = 8
# Saving model checkpoint to ./vit-base-mask-finetuned/checkpoint-100
# Configuration saved in ./vit-base-mask-finetuned/checkpoint-100/config.json
# Model weights saved in ./vit-base-mask-finetuned/checkpoint-100/pytorch_model.bin
# Configuration saved in ./vit-base-mask-finetuned/checkpoint-100/preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 3596
#   Batch size = 8
# Saving model checkpoint to ./vit-base-mask-finetuned/checkpoint-200
# Configuration saved in ./vit-base-mask-finetuned/checkpoint-200/config.json
# Model weights saved in ./vit-base-mask-finetuned/checkpoint-200/pytorch_model.bin
# Configuration saved in ./vit-base-mask-finetuned/checkpoint-200/preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 3596
#   Batch size = 8
# Saving model checkpoint to ./vit-base-mask-finetuned/checkpoint-300
# Configuration saved in ./vit-base-mask-finetuned/checkpoint-300/config.json
# Model weights saved in ./vit-base-mask-finetuned/checkpoint-300/pytorch_model.bin
# Configuration saved in ./vit-base-mask-finetuned/checkpoint-300/preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 3596
#   Batch size = 8
# Saving model checkpoint to ./vit-base-mask-finetuned/checkpoint-400
# Configuration saved in ./vit-base-mask-finetuned/checkpoint-400/config.json
# Model weights saved in ./vit-base-mask-finetuned/checkpoint-400/pytorch_model.bin
# Configuration saved in ./vit-base-mask-finetuned/checkpoint-400/preprocessor_config.json
# ***** Running Evaluation *****
#   Num examples = 3596
#   Batch size = 8
# Saving model checkpoint to ./vit-base-mask-finetuned/checkpoint-500
# Configuration saved in ./vit-base-mask-finetuned/checkpoint-500/config.json
# Model weights saved in ./vit-base-mask-finetuned/checkpoint-500/pytorch_model.bin
# Configuration saved in ./vit-base-mask-finetuned/checkpoint-500/preprocessor_config.json
# Deleting older checkpoint [vit-base-mask-finetuned/checkpoint-100] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 3596
#   Batch size = 8
# Saving model checkpoint to ./vit-base-mask-finetuned/checkpoint-600
# Configuration saved in ./vit-base-mask-finetuned/checkpoint-600/config.json
# Model weights saved in ./vit-base-mask-finetuned/checkpoint-600/pytorch_model.bin
# Configuration saved in ./vit-base-mask-finetuned/checkpoint-600/preprocessor_config.json
# Deleting older checkpoint [vit-base-mask-finetuned/checkpoint-200] due to args.save_total_limit
# ***** Running Evaluation *****
#   Num examples = 3596
#   Batch size = 8
# Saving model checkpoint to ./vit-base-mask-finetuned/checkpoint-700
# Configuration saved in ./vit-base-mask-finetuned/checkpoint-700/config.json
# Model weights saved in ./vit-base-mask-finetuned/checkpoint-700/pytorch_model.bin
# Configuration saved in ./vit-base-mask-finetuned/checkpoint-700/preprocessor_config.json
# Deleting older checkpoint [vit-base-mask-finetuned/checkpoint-300] due to args.save_total_limit
#     <div>
#
#       <progress value='800' max='3608' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [ 800/3608 40:09 < 2:21:19, 0.33 it/s, Epoch 0/4]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>0.021400</td>
#       <td>0.155222</td>
#       <td>0.961346</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.041500</td>
#       <td>0.061964</td>
#       <td>0.986374</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.037200</td>
#       <td>0.058919</td>
#       <td>0.984983</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.073800</td>
#       <td>0.173725</td>
#       <td>0.927419</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.009600</td>
#       <td>0.039475</td>
#       <td>0.989433</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.058400</td>
#       <td>0.175120</td>
#       <td>0.949944</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.009700</td>
#       <td>0.045691</td>
#       <td>0.987764</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.046500</td>
#       <td>0.040168</td>
#       <td>0.989711</td>
#     </tr>
#   </tbody>
# </table><p>
# ***** Running Evaluation *****
#   Num examples = 3596
#   Batch size = 8
# Saving model checkpoint to ./vit-base-mask-finetuned/checkpoint-800
# Configuration saved in ./vit-base-mask-finetuned/checkpoint-800/config.json
# Model weights saved in ./vit-base-mask-finetuned/checkpoint-800/pytorch_model.bin
# Configuration saved in ./vit-base-mask-finetuned/checkpoint-800/preprocessor_config.json
# Deleting older checkpoint [vit-base-mask-finetuned/checkpoint-400] due to args.save_total_limit
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# Loading best model from ./vit-base-mask-finetuned/checkpoint-500 (score: 0.03947526961565018).
# Saving model checkpoint to ./vit-base-mask-finetuned
# Configuration saved in ./vit-base-mask-finetuned/config.json
# Model weights saved in ./vit-base-mask-finetuned/pytorch_model.bin
# Configuration saved in ./vit-base-mask-finetuned/preprocessor_config.json
# ***** train metrics *****
#   epoch                    =        0.89
#   total_flos               = 923776502GF
#   train_loss               =       0.057
#   train_runtime            =  0:40:10.40
#   train_samples_per_second =      23.943
#   train_steps_per_second   =       1.497

# %%
metrics = trainer.evaluate(test_ds)
trainer.log_metrics("eval", metrics)
trainer.save_metrics("eval", metrics)
# Out:
# ***** Running Evaluation *****
#   Num examples = 3596
#   Batch size = 8
#     <div>
#
#       <progress value='450' max='450' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [450/450 00:36]
#     </div>
# ***** eval metrics *****
#   epoch                   =       0.89
#   eval_accuracy           =     0.9894
#   eval_loss               =     0.0395
#   eval_runtime            = 0:00:36.81
#   eval_samples_per_second =     97.685
#   eval_steps_per_second   =     12.224

# %%
# !zip -r vit-base-mask-finetuned.zip vit-base-mask-finetuned/
# Out:
#   adding: vit-base-mask-finetuned/ (stored 0%)
#   adding: vit-base-mask-finetuned/runs/ (stored 0%)
#   adding: vit-base-mask-finetuned/runs/Feb17_12-52-55_0ef67e2ff67c/ (stored 0%)
#   adding: vit-base-mask-finetuned/runs/Feb17_12-52-55_0ef67e2ff67c/events.out.tfevents.1645102429.0ef67e2ff67c.84.0 (deflated 58%)
#   adding: vit-base-mask-finetuned/runs/Feb17_12-52-55_0ef67e2ff67c/1645102429.3300188/ (stored 0%)
#   adding: vit-base-mask-finetuned/runs/Feb17_12-52-55_0ef67e2ff67c/1645102429.3300188/events.out.tfevents.1645102429.0ef67e2ff67c.84.1 (deflated 62%)
#   adding: vit-base-mask-finetuned/runs/Feb17_13-36-51_0ef67e2ff67c/ (stored 0%)
#   adding: vit-base-mask-finetuned/runs/Feb17_13-36-51_0ef67e2ff67c/events.out.tfevents.1645105012.0ef67e2ff67c.84.2 (deflated 65%)
#   adding: vit-base-mask-finetuned/runs/Feb17_13-36-51_0ef67e2ff67c/1645105012.531838/ (stored 0%)
#   adding: vit-base-mask-finetuned/runs/Feb17_13-36-51_0ef67e2ff67c/1645105012.531838/events.out.tfevents.1645105012.0ef67e2ff67c.84.3 (deflated 62%)
#   adding: vit-base-mask-finetuned/runs/Feb17_13-36-51_0ef67e2ff67c/events.out.tfevents.1645107987.0ef67e2ff67c.84.4 (deflated 27%)
#   adding: vit-base-mask-finetuned/checkpoint-500/ (stored 0%)
#   adding: vit-base-mask-finetuned/checkpoint-500/config.json (deflated 46%)
#   adding: vit-base-mask-finetuned/checkpoint-500/pytorch_model.bin (deflated 7%)
#   adding: vit-base-mask-finetuned/checkpoint-500/preprocessor_config.json (deflated 46%)
#   adding: vit-base-mask-finetuned/checkpoint-500/training_args.bin (deflated 49%)
#   adding: vit-base-mask-finetuned/checkpoint-500/optimizer.pt (deflated 7%)
#   adding: vit-base-mask-finetuned/checkpoint-500/scheduler.pt (deflated 49%)
#   adding: vit-base-mask-finetuned/checkpoint-500/scaler.pt (deflated 55%)
#   adding: vit-base-mask-finetuned/checkpoint-500/trainer_state.json (deflated 81%)
#   adding: vit-base-mask-finetuned/checkpoint-500/rng_state.pth (deflated 27%)
#   adding: vit-base-mask-finetuned/checkpoint-600/ (stored 0%)
#   adding: vit-base-mask-finetuned/checkpoint-600/config.json (deflated 46%)
#   adding: vit-base-mask-finetuned/checkpoint-600/pytorch_model.bin (deflated 7%)
#   adding: vit-base-mask-finetuned/checkpoint-600/preprocessor_config.json (deflated 46%)
#   adding: vit-base-mask-finetuned/checkpoint-600/training_args.bin (deflated 49%)
#   adding: vit-base-mask-finetuned/checkpoint-600/optimizer.pt (deflated 7%)
#   adding: vit-base-mask-finetuned/checkpoint-600/scheduler.pt (deflated 49%)
#   adding: vit-base-mask-finetuned/checkpoint-600/scaler.pt (deflated 55%)
#   adding: vit-base-mask-finetuned/checkpoint-600/trainer_state.json (deflated 82%)
#   adding: vit-base-mask-finetuned/checkpoint-600/rng_state.pth (deflated 27%)
#   adding: vit-base-mask-finetuned/checkpoint-700/ (stored 0%)
#   adding: vit-base-mask-finetuned/checkpoint-700/config.json (deflated 46%)
#   adding: vit-base-mask-finetuned/checkpoint-700/pytorch_model.bin (deflated 7%)
#   adding: vit-base-mask-finetuned/checkpoint-700/preprocessor_config.json (deflated 46%)
#   adding: vit-base-mask-finetuned/checkpoint-700/training_args.bin (deflated 49%)
#   adding: vit-base-mask-finetuned/checkpoint-700/optimizer.pt (deflated 7%)
#   adding: vit-base-mask-finetuned/checkpoint-700/scheduler.pt (deflated 49%)
#   adding: vit-base-mask-finetuned/checkpoint-700/scaler.pt (deflated 55%)
#   adding: vit-base-mask-finetuned/checkpoint-700/trainer_state.json (deflated 82%)
#   adding: vit-base-mask-finetuned/checkpoint-700/rng_state.pth (deflated 27%)
#   adding: vit-base-mask-finetuned/checkpoint-800/ (stored 0%)
#   adding: vit-base-mask-finetuned/checkpoint-800/config.json (deflated 46%)
#   adding: vit-base-mask-finetuned/checkpoint-800/pytorch_model.bin (deflated 7%)
#   adding: vit-base-mask-finetuned/checkpoint-800/preprocessor_config.json (deflated 46%)
#   adding: vit-base-mask-finetuned/checkpoint-800/training_args.bin (deflated 49%)
#   adding: vit-base-mask-finetuned/checkpoint-800/optimizer.pt (deflated 7%)
#   adding: vit-base-mask-finetuned/checkpoint-800/scheduler.pt (deflated 49%)
#   adding: vit-base-mask-finetuned/checkpoint-800/scaler.pt (deflated 55%)
#   adding: vit-base-mask-finetuned/checkpoint-800/trainer_state.json (deflated 83%)
#   adding: vit-base-mask-finetuned/checkpoint-800/rng_state.pth (deflated 27%)
#   adding: vit-base-mask-finetuned/config.json (deflated 46%)
#   adding: vit-base-mask-finetuned/pytorch_model.bin (deflated 7%)
#   adding: vit-base-mask-finetuned/preprocessor_config.json (deflated 46%)
#   adding: vit-base-mask-finetuned/training_args.bin (deflated 49%)
#   adding: vit-base-mask-finetuned/train_results.json (deflated 37%)
#   adding: vit-base-mask-finetuned/all_results.json (deflated 51%)
#   adding: vit-base-mask-finetuned/trainer_state.json (deflated 83%)
#   adding: vit-base-mask-finetuned/eval_results.json (deflated 38%)
